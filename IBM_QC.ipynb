# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Quantum-Computing/blob/main/IBM_QC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit

# %%
pip install qiskit-ibm-runtime

# %%
pip install pylatexenc

# %%
pip install qiskit-aer

# %%
import matplotlib.pyplot as plt

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# %%
QiskitRuntimeService.save_account(
    channel ="ibm_quantum_platform",
    token = "1Z5wfRvWDqKiE5oMAfNQ9eftFBwmG-Yw9xZxg6ju4Yem",
    instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/56758199c2674cca99b45e7d254aa579:19f04a90-88ac-4e8b-a74a-799725b65ca9::",
    overwrite =True

)

# %%
from qiskit import QuantumCircuit
from qiskit import transpile
from qiskit_aer import AerSimulator
qc =QuantumCircuit(2,2)
qc.h(0)
qc.cx(0,1)
qc.measure([0,1],[0,1])
#qc.draw("text")

service = QiskitRuntimeService()

#to check we can use it or does it contain space or does it contain any simulator or not...
backend =service.least_busy(
    operational=True,
    simulator=False
)

print(backend.name)

compile =transpile(qc,backend)

from qiskit_ibm_runtime import SamplerV2 as sampler
sampler = sampler(backend)
process = sampler.run([compile],shots = 1024)
id = process.job_id()
print(id)
print("---------------")

result= process.result()

print("--------------------")
print(process.result())


final_result = result[0]

print(final_result)
xyz =final_result.data.c
counts =xyz.get_counts()
print(counts)
# Out:
# ibm_marrakesh
# d9dpfnineu4c739nivgg
# ---------------
# --------------------
# PrimitiveResult([SamplerPubResult(data=DataBin(c=BitArray(<shape=(), num_shots=1024, num_bits=2>)), metadata={'circuit_metadata': {}})], metadata={'execution': {'execution_spans': ExecutionSpans([DoubleSliceSpan(<start='2026-07-18 15:12:33', stop='2026-07-18 15:12:34', size=1024>)])}, 'version': 2})
# SamplerPubResult(data=DataBin(c=BitArray(<shape=(), num_shots=1024, num_bits=2>)), metadata={'circuit_metadata': {}})
# {'11': 457, '00': 531, '10': 33, '01': 3}
