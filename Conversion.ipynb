# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Quantum-Computing/blob/main/Conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def binary(number):
  binary=""
  value=1
  while number > 0:
    digit = number %2
    binary = str(digit) + binary
    number = number // 2

  print(binary)
binary(232)
# Out:
# 11101000

# %%
def binary(number):
  binary=""
  value=1
  while number > 0:
    digit = number %2
    binary = str(digit) + binary
    number = number // 2

  print(binary)

binary(539)
binary(621)
# Out:
# 1000011011
# 1001101101

# %%
def add(b1,b2):
  binary = 0
  value = 1
  num = 0
  while b1>0 or b2>0 or num>0:
    digit = (b1%10)+(b2%10)+num
    binary= binary + ((digit%2)*value)
    num = digit //2
    value = value * 10
    b1=b1//10
    b2=b2//10
  print(binary)

add(101,101)
# Out:
# 1010
