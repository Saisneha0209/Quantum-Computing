# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Quantum-Computing/blob/main/Quantum_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit
# Out:
# Collecting qiskit
#   Downloading qiskit-2.5.1-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.14 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.9.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.16.0)
# Downloading qiskit-2.5.1-cp310-abi3-manylinux_2_28_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 57.3 MB/s eta 0:00:00
# Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.0 MB/s eta 0:00:00
# Downloading stevedore-5.9.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: stevedore, rustworkx, qiskit
# Successfully installed qiskit-2.5.1 rustworkx-0.18.0 stevedore-5.9.0

# %%
# !pip install qiskit-machine-learning
# Out:
# Collecting qiskit-machine-learning
#   Downloading qiskit_machine_learning-0.9.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: qiskit>=2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (2.5.1)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (2.0.2)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (1.6.1)
# Requirement already satisfied: setuptools>=40.1 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (75.2.0)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (0.3.8)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.0->qiskit-machine-learning) (0.18.0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.0->qiskit-machine-learning) (5.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.0->qiskit-machine-learning) (4.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2->qiskit-machine-learning) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2->qiskit-machine-learning) (3.6.0)
# Downloading qiskit_machine_learning-0.9.0-py3-none-any.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.1/263.1 kB 9.1 MB/s eta 0:00:00
# Installing collected packages: qiskit-machine-learning
# Successfully installed qiskit-machine-learning-0.9.0

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
import matplotlib.pyplot as plt
import qiskit
import qiskit_machine_learning
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
from sklearn.decomposition import PCA
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

housing = fetch_california_housing(as_frame = True)
df = housing.frame

print("First 5 row")
print(df.head())

print("DATASET INFO")
print(df.info())


print(df.describe())

x = housing.data
y = housing.target

x_train,x_test,y_train,y_test =train_test_split(x,y,test_size =0.2 , random_state = 42)

scaler = StandardScaler()
x_train_scale = scaler.fit_transform(x_train)
x_test_scale = scaler.transform(x_test)


dt_model = DecisionTreeRegressor()
dt_model.fit(x_train_scale,y_train)

dt_pred =dt_model.predict(x_test_scale)
dt_rmse = np.sqrt(mean_squared_error(y_test,dt_pred))
dt_r2 = r2_score(y_test,dt_pred)

print("---DECISION TREE---")
print(f"RMSE USING DECISION TREE:{dt_rmse}")
print(f"R2 USING DECISION TREE:{dt_r2}")

rf_model = RandomForestRegressor()
rf_model.fit(x_train_scale,y_train)
rf_pred = rf_model.predict(x_test_scale)
rf_rmse = np.sqrt(mean_squared_error(y_test,rf_pred))
rf_r2 = r2_score(y_test,rf_pred)

print("---Random Forest---")
print("RMSE USING RANDOM FOREST:",rf_rmse)
print("R2 SCORE USING RANDOM FOREST:",rf_r2)

model = LinearRegression()
model.fit(x_train_scale,y_train)

y_pred = model.predict(x_test_scale)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test,y_pred)
print("--LINEAR REGRESSION---")
print(f"RMSE USING LINEAR REGRESSION: {rmse}")
print(f"R2 SCORE USING LINEAR REGRESSION: {r2}")
# Out:
# First 5 row
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422
# DATASET INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# None
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010
# ---DECISION TREE---
# RMSE USING DECISION TREE:0.7047442918420919
# R2 USING DECISION TREE:0.6209851083661402
# ---Random Forest---
# RMSE USING RANDOM FOREST: 0.5035969575357807
# R2 SCORE USING RANDOM FOREST: 0.8064650808637299
# --LINEAR REGRESSION---
# RMSE USING LINEAR REGRESSION: 0.7455813830127763
# R2 SCORE USING LINEAR REGRESSION: 0.575787706032451

# %%
#BY PCA
pca  = PCA(n_components= 5,random_state = 42)
x_train_pca = pca.fit_transform(x_train_scale)
x_test_pca = pca.transform(x_test_scale)

#DECISION TREE WITH PCA DATA
dt_model = DecisionTreeRegressor()
dt_model.fit(x_train_pca,y_train)

dt_pred =dt_model.predict(x_test_pca)
dt_rmse = np.sqrt(mean_squared_error(y_test,dt_pred))
dt_r2 = r2_score(y_test,dt_pred)

print("---DECISION TREE (PCA) ---")
print(f"RMSE USING DECISION TREE:{dt_rmse}")
print(f"R2 USING DECISION TREE:{dt_r2}")

#RANDOM FOREST WITH PCA

rf_model = RandomForestRegressor()
rf_model.fit(x_train_pca,y_train)
rf_pred = rf_model.predict(x_test_pca)
rf_rmse = np.sqrt(mean_squared_error(y_test,rf_pred))
rf_r2 = r2_score(y_test,rf_pred)

print("---Random Forest (PCA) ---")
print("RMSE USING RANDOM FOREST:",rf_rmse)
print("R2 SCORE USING RANDOM FOREST:",rf_r2)
# Out:
# ---DECISION TREE (PCA) ---
# RMSE USING DECISION TREE:1.0422274652085914
# R2 USING DECISION TREE:0.17106940865645015
# ---Random Forest (PCA) ---
# RMSE USING RANDOM FOREST: 0.7481042574307804
# R2 SCORE USING RANDOM FOREST: 0.5729119768872846

# %%
from qiskit.circuit.library import ZZFeatureMap, RealAmplitudes
from qiskit.primitives import StatevectorEstimator
from qiskit_machine_learning.algorithms import VQR
from qiskit_machine_learning.optimizers import COBYLA
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error,r2_score

housing = fetch_california_housing(as_frame = True)
x = housing.data
y = housing.target

scaler = MinMaxScaler()
x_train_scale = scaler.fit_transform(x)
x_test_scale = scaler.transform(x)

pca  = PCA(n_components= 2,random_state = 42)
x_train_pca = pca.fit_transform(x_train_scale)
x_test_pca = pca.transform(x_test_scale)


x_train,x_test,y_train,y_test =train_test_split(x_train_pca,y,test_size =0.2 , random_state = 42)

feature_map = ZZFeatureMap(feature_dimension = 2,reps = 2)

answer = RealAmplitudes(num_qubits =2,reps = 2)

optimizer =COBYLA(maxiter = 100)
estimator = StatevectorEstimator()
vqr = VQR(feature_map = feature_map,
          ansatz =answer,
          optimizer = optimizer,
          estimator = estimator)

vqr.fit(x_train,y_train)
print("Training complete")

y_pred = vqr.predict(x_test_pca)

mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test,y_pred)
print("RMSE:",rmse)
print("R2 Score:",r2)
# Out:
# /tmp/ipykernel_2609/3936268928.py:23: DeprecationWarning: The class ``qiskit.circuit.library.data_preparation._zz_feature_map.ZZFeatureMap`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. Use the zz_feature_map function as a replacement. Note that this will no longer return a BlueprintCircuit, but just a plain QuantumCircuit.
#   feature_map = ZZFeatureMap(feature_dimension = 2,reps = 2)
# /tmp/ipykernel_2609/3936268928.py:25: DeprecationWarning: The class ``qiskit.circuit.library.n_local.real_amplitudes.RealAmplitudes`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. Use the function qiskit.circuit.library.real_amplitudes instead.
#   answer = RealAmplitudes(num_qubits =2,reps = 2)
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2609/3936268928.py in <cell line: 0>()
#      32           estimator = estimator)
#      33
# ---> 34 vqr.fit(x_train,y_train)
#      35 print("Training complete")
#      36
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/algorithms/trainable_model.py in fit(self, X, y)
#     200             self._fit_result = None
#     201
# --> 202         self._fit_result = self._fit_internal(X, y)
#     203         return self
#     204
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/algorithms/regressors/neural_network_regressor.py in _fit_internal(self, X, y)
#      40             function = MultiClassObjectiveFunction(X, y, self._neural_network, self._loss)
#      41
# ---> 42         return self._minimize(function)
#      43
#      44     def predict(self, X: np.ndarray) -> np.ndarray:  # pylint: disable=invalid-name
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/algorithms/trainable_model.py in _minimize(self, function)
#     297             )
#     298         else:
# --> 299             optimizer_result = self._optimizer.minimize(
#     300                 fun=objective,
#     301                 x0=initial_point,
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/optimizers/scipy_optimizer.py in minimize(self, fun, x0, jac, bounds)
#     145             self._options["maxfun"] = self._options.pop("maxiter")
#     146
# --> 147         raw_result = minimize(
#     148             fun=fun,
#     149             x0=x0,
#
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     788                             **options)
#     789     elif meth == 'cobyla':
# --> 790         res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     791                                bounds=bounds, **options)
#     792     elif meth == 'cobyqa':
#
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_cobyla_py.py in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, f_target, callback, bounds, **unknown_options)
#     276     }
#     277
# --> 278     result = minimize(sf.fun, x0, method='cobyla', bounds=bounds,
#     279                       constraints=constraints, callback=wrapped_callback,
#     280                       options=options)
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/pyprima/__init__.py in minimize(fun, x0, args, method, bounds, constraints, callback, options)
#     189         del options['maxfev']
#     190
# --> 191     result = cobyla(
#     192         calcfc,
#     193         len(nlconstr0),
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/pyprima/cobyla/cobyla.py in cobyla(calcfc, m_nlcon, x, Aineq, bineq, Aeq, beq, xl, xu, f0, nlconstr0, rhobeg, rhoend, ftarget, ctol, cweight, maxfun, iprint, eta1, eta2, gamma1, gamma2, maxhist, maxfilt, callback)
#     459
#     460     # call cobylb, which performs the real calculations
# --> 461     x, f, constr, cstrv, nf, xhist, fhist, chist, conhist, info = cobylb(
#     462         calcfc,
#     463         iprint,
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/pyprima/cobyla/cobylb.py in cobylb(calcfc, iprint, maxfilt, maxfun, amat, bvec, ctol, cweight, eta1, eta2, ftarget, gamma1, gamma2, rhobeg, rhoend, constr, f, x, maxhist, callback)
#     476                 # Evaluate the objective and constraints at X, taking care of possible
#     477                 # inf/nan values.
# --> 478                 f, constr = evaluate(calcfc, x, m_nlcon, amat, bvec)
#     479                 cstrv = np.max(np.append(0, constr))
#     480                 nf += 1
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/pyprima/common/evaluate.py in evaluate(calcfc, x, m_nlcon, amat, bvec)
#      78         constr = np.ones(m_nlcon) * f
#      79     else:
# ---> 80         f, constr[m_lcon:] = calcfc(moderatex(x))
#      81
#      82         # Moderated extreme barrier: replace NaN/huge objective or constraint values
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/pyprima/__init__.py in calcfc(x)
#     176     else:
#     177         def calcfc(x):
# --> 178             f = fun(x, *args)
#     179             constr = np.zeros(0)
#     180             return f, constr
#
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_differentiable_functions.py in fun(self, x)
#     383         if not np.array_equal(x, self.x):
#     384             self._update_x(x)
# --> 385         self._update_fun()
#     386         return self.f
#     387
#
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     351     def _update_fun(self):
#     352         if not self.f_updated:
# --> 353             fx = self._wrapped_fun(self.x)
#     354             self._nfev += 1
#     355             if fx < self._lowest_f:
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py in __call__(self, x)
#     588         # Send a copy because the user may overwrite it.
#     589         # The user of this class might want `x` to remain unchanged.
# --> 590         fx = self.f(np.copy(x), *self.args)
#     591         self.nfev += 1
#     592
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/algorithms/objective_functions.py in objective(self, weights)
#     112     def objective(self, weights: np.ndarray) -> float:
#     113         # predict is of shape (N, 1), where N is a number of samples
# --> 114         predict = self._neural_network_forward(weights)
#     115         target = np.array(self._y).reshape(predict.shape)
#     116         # float(...) is for mypy compliance
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/algorithms/objective_functions.py in _neural_network_forward(self, weights)
#      99         ):
#     100             # compute forward and cache the results for re-use in backward
# --> 101             self._last_forward = self._neural_network.forward(self._X, weights)
#     102             # a copy avoids keeping a reference to the same array, so we are sure we have
#     103             # different arrays on the next iteration.
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/neural_networks/neural_network.py in forward(self, input_data, weights)
#     227         input_, shape = self._validate_input(input_data)
#     228         weights_ = self._validate_weights(weights)
# --> 229         output_data = self._forward(input_, weights_)
#     230         return self._validate_forward_output(output_data, shape)
#     231
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/neural_networks/estimator_qnn.py in _forward(self, input_data, weights)
#     252         # For BaseEstimatorV2, run the estimator using PUBs and specified precision
#     253         job = self.estimator.run(circuit_observable_params, precision=self._default_precision)
# --> 254         results = [result.data.evs for result in job.result()]
#     255         return self._forward_postprocess(num_samples, results)
#     256
#
# /usr/local/lib/python3.12/dist-packages/qiskit/primitives/primitive_job.py in result(self)
#      70         if self._result is None:
#      71             self._check_submitted()
# ---> 72             self._result = self._future.result()
#      73         return self._result
#      74
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     449                     return self.__get_result()
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#     453                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     353         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#     357             else:
#
# KeyboardInterrupt:
