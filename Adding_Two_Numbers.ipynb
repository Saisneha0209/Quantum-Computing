# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Quantum-Computing/blob/main/Adding_Two_Numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 2.6 MB/s eta 0:00:00
# ...

# %%
pip install qiskit_aer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 26.5 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile
qc = QuantumCircuit(5, 2)
qc.x(0)
qc.x(1)

qc.cx(0, 3)
qc.cx(1, 3)
qc.ccx(0,1,4)

qc.measure(3, 0)
qc.measure(4, 1)

simulator = AerSimulator()
compile =transpile(qc,simulator)
result = simulator.run(compile,shots = 10000).result()
count = result.get_counts()
print("Result:", count)
# Out:
# Result: {'10': 10000}
