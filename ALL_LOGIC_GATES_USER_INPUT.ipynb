# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Quantum-Computing/blob/main/ALL_LOGIC_GATES_USER_INPUT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = (input("Enter value for A: "))
b = (input("Enter value for B: "))
if a == 1 and b == 1:
    gate_and = 1
else:
    gate_and = 0

if a == 1 or b == 1:
    gate_or = 1
else:
    gate_or = 0

if gate_and == 1:
    gate_nand = 0
else:
    gate_nand = 1

if gate_or == 1:
    gate_nor = 0
else:
    gate_nor = 1

if a != b:
    gate_xor = 1
else:
    gate_xor = 0

if gate_xor == 1:
    gate_xnor = 0
else:
    gate_xnor = 1

print("AND  Gate =", gate_and)
print("OR   Gate =", gate_or)
print("NAND Gate =", gate_nand)
print("NOR  Gate =", gate_nor)
print("XOR  Gate =", gate_xor)
print("XNOR Gate =", gate_xnor)
# Out:
# Enter value for A: 1
# Enter value for B: 0
# AND  Gate = 0
# OR   Gate = 0
# NAND Gate = 1
# NOR  Gate = 1
# XOR  Gate = 1
# XNOR Gate = 0

# %%
a = int(input("Enter value for A: "))
b = int(input("Enter value for B: "))

gate_and = 1 if (a == 1 and b == 1) else 0
gate_or =1 if(a == 1 or b == 1) else 0
gate_nand =0 if (gate_and == 1) else 1
gate_nor = 0 if(gate_or == 1) else 1
gate_xor =1 if (a != b) else 0
gate_xnor = 0 if(gate_xor == 1) else 1

print("AND Gate =", gate_and)
print("OR Gate =", gate_or)
print("NAND Gate =",gate_nand)
print("NOR Gate =",gate_nor)
print("XOR Gate =",gate_xor)
print("XNOR Gate =", gate_xnor)
# Out:
# Enter value for A: 1
# Enter value for B: 0
# AND Gate = 0
# OR Gate = 1
# NAND Gate = 1
# NOR Gate = 0
# XOR Gate = 1
# XNOR Gate = 0

# %%
def main():
  gate=input("choose a gate:").upper()
  if gate == "NOT":
    a = int(input("enter a:"))
    if a ==0:
      result= 1
    else:
      result=0

    print(f"Result:Not{a}={result}")
    return

  if gate in ["AND","OR","NAND","NOR","XOR"]:
    print("gate selected!")
    result = 0
    a=int(input("enter a :"))
    b=int(input("enter b :"))

    if gate == "AND":
      if a == 1:
        if b ==1:
          result = 1
        else:
          result = 0
      else:
        result = 0

    elif gate =="OR":
      if a == 1:
        result =1
      elif b==1:
        result=1
      else:
        result = 0

    elif gate =="NAND":
      if a == 1:
        if b == 1:
          result = 0
        else:
          result = 1
      else:
        result=1

    elif gate =="NOR":
      if a == 0 :
        if b ==0:
          result = 1
        else:
          result = 0
      else:
        result = 0

    elif gate == "XOR":
      if a!=b:
        result = 1
      else:
        result = 0

    print(f"Result:{a}{gate}{b}={result}")
  else:
    print("invalid gate")

main()
# Out:
# choose a gate:OR
# gate selected!
# enter a :1
# enter b :0
# Result:1OR0=1
